# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonOrchid11/Covid19-Analysis/blob/master/gender_ageDETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# !python3 gad.py
# Out:
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0

# %%
img = mpimg.imread('girl1.jpg')
plt.imshow(img)
# !python3 gad.py --image girl1.jpg
# Out:
# Gender: Female
# Age: 25-32 years
# <Figure size 640x480 with 1 Axes>

# %%
img = mpimg.imread('woman1.jpg')
plt.imshow(img)
# !python3 gad.py --image woman1.jpg
# Out:
# Gender: Female
# Age: 38-43 years
# <Figure size 640x480 with 1 Axes>

# %%
img = mpimg.imread('man1.jpg')
plt.imshow(img)
# !python3 gad.py --image man1.jpg
# Out:
# Gender: Male
# Age: 60-100 years
# <Figure size 640x480 with 1 Axes>

# %%
img = mpimg.imread('kid1.jpg')
plt.imshow(img)
# !python3 gad.py --image kid1.jpg
# Out:
# Gender: Male
# Age: 4-6 years
# <Figure size 640x480 with 1 Axes>

# %%
img = mpimg.imread('woman3.jpg')
plt.imshow(img)
# !python3 gad.py --image woman3.jpg
# Out:
# Gender: Female
# Age: 48-53 years
# <Figure size 640x480 with 1 Axes>
